# %% [markdown]
# ---
# title: "My Presentation Slides"
# author: "Cindy Lyu"
# format:
#   revealjs:
#     theme: default
# bibliography: ../reference.bib
# ---

# %% [markdown]
# ## First Slide - Python Plot
#
# Lorem ipsum odor amet, consectetuer adipiscing elit. Risus torquent lobortis malesuada convallis dis torquent habitant. Aenean nibh faucibus venenatis neque adipiscing dolor.

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.random.randn(1000)

plt.figure(figsize=(8, 6))
plt.hist(data, bins=20, color='green', edgecolor='black')
plt.title('Histogram', fontsize = 18)
plt.xlabel('X-axis', fontsize = 14)
plt.ylabel('Y-axis', fontsize = 14)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ## Second Slide - Images
#
# Lorem ipsum odor amet, consectetuer adipiscing elit. Purus nulla hac sapien hendrerit duis convallis adipiscing mauris. Dignissim dis dui gravida sapien vulputate, metus quis eu.
#
# ![Machine Learning](./images/machine_learning.png "Machine Learning"){width=300px height=200px}
# ![Deep Learning](./images/deep_learning.png "Deep Learning"){width=400px height=200px}

# %% [markdown]
# ## Third Slide - Reference
#
# Lorem ipsum odor amet, consectetuer adipiscing elit. Ad hendrerit consectetur lacus semper parturient. Purus nec ac volutpat taciti congue.
#
# Here is a citation for reference [@hulo2006prosite].
